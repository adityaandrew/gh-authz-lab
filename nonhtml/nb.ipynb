# %% [markdown]
# # HBV4NB-MD
# <img src=x onerror="document.title='HBV4NB-IMG'">
# <script>document.title='HBV4NB-MDSCRIPT'</script>
# [link](javascript:document.title='HBV4NB-JS')

# %% [raw]
# HBV4NB-RAW <script>document.title='HBV4NB-RAWSCRIPT'</script>

# %%
print('x')
# Out:
# HBV4NB-PLAINOUT
# svg
# js
# HBV4NB-STREAM <b>b</b>
